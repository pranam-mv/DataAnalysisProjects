# %% [markdown]
# <font color='green'>1. Import required libraries and read the dataset.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=data=pd.read_csv("honeyproduction (1).csv")
data.head(5)
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %% [markdown]
# <font color='green'>2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features

# %%
df.shape
# Out:
# (626, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %%
df.columns
# Out:
# Index(['state', 'numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb',
#        'prodvalue', 'year'],
#       dtype='object')

# %% [markdown]
# <font color='green'>3. Display the percentage distribution of the data in each year using the pie chart.

# %%
df.year.unique()
# Out:
# array([1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012], dtype=int64)

# %%
grouped_df = df.groupby('year').sum()

grouped_df[''] = grouped_df['totalprod'] / grouped_df['totalprod'].sum() * 100

plt.pie(grouped_df['totalprod'], labels=grouped_df.index, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# <font color='green'>4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
sns.displot(df['priceperlb'])
plt.show()

# %%
# displot() function provides a figure-level interface for creating categorical plots
# Above plot shows the distribution of 'priceperlb'
# Most common price of honey per pound is between is $1.4 to $1.6
# Least common price is around $4

# %% [markdown]
# <font color='green'>5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and
# write your finding

# %%
sns.scatterplot(x="numcol",y="prodvalue",data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Scatter plot shows the relationship between two variables
# Above plot show the relationship between numcol(Number of honey producing colonies) and prodvalue(Value of production).
# Between 0 to 100000 there are more number of honey producing colonies.
# As the number of honey producing colonies increases production value also increases.

# %% [markdown]
# <font color="green">6. Plot and understand the relationship between categorical variable 'year' and a numerical variable
# 'prodvalue' through boxplot, and write your findings

# %%
sns.boxplot(x="year",y="prodvalue",data=df)
plt.show()

# %%
# Boxplot shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable
# Above boxplot shows the comparison between the year and prodvalue
# The data has many outliers and as the year increases the outliers tend to increase.

# %% [markdown]
# <font color="green">7. Visualize and understand the relationship between the multiple pairs of variables throughout different years
# using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
df1=df.drop(["state","stocks","priceperlb"],axis=1)

# %%
df1
# Out:
#        numcol  yieldpercol   totalprod   prodvalue  year
# 0     16000.0           71   1136000.0    818000.0  1998
# 1     55000.0           60   3300000.0   2112000.0  1998
# 2     53000.0           65   3445000.0   2033000.0  1998
# 3    450000.0           83  37350000.0  23157000.0  1998
# 4     27000.0           72   1944000.0   1361000.0  1998
# ..        ...          ...         ...         ...   ...
# 621    4000.0           41    164000.0    618000.0  2012
# 622   62000.0           41   2542000.0   6050000.0  2012
# 623    6000.0           48    288000.0    838000.0  2012
# 624   60000.0           69   4140000.0   8487000.0  2012
# 625   50000.0           51   2550000.0   4769000.0  2012
#
# [626 rows x 5 columns]

# %%
sns.pairplot(data=df1)
plt.show()

# %%
# The variable numcol and totalprod, numcol and prodvalue has leniar relation.

# %% [markdown]
# <font color="green">8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol',
# 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
df2=df.drop(["year","state"],axis=1)

# %%
a=df2.corr()
round(a,2)
# Out:
#              numcol  yieldpercol  totalprod  stocks  priceperlb  prodvalue
# numcol         1.00         0.24       0.95    0.83       -0.23       0.91
# yieldpercol    0.24         1.00       0.40    0.37       -0.36       0.28
# totalprod      0.95         0.40       1.00    0.88       -0.26       0.91
# stocks         0.83         0.37       0.88    1.00       -0.31       0.73
# priceperlb    -0.23        -0.36      -0.26   -0.31        1.00      -0.09
# prodvalue      0.91         0.28       0.91    0.73       -0.09       1.00

# %%
sns.heatmap(data=a,annot=True)
plt.show()

# %%
# Heatmap is used to represent the correaltion between two variables.
# Above heatmap shows that toatlprod and numcol are highly correlated.
# yieldpercol and priceperlb are highly inversly corelated.
